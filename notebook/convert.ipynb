# %%
import pandas as pd

# %%
df = pd.read_parquet('../data/df_final.parquet')

df.sample(5)
# Out:
#                            time  kemendagri_kabupaten_kode  \
# 58877 2022-08-10 17:00:00+00:00                      32.71
# 32803 2022-07-26 14:00:00+00:00                      32.71
# 8206  2022-07-11 17:00:00+00:00                      32.71
# 5532  2022-07-09 16:00:00+00:00                      32.71
# 89233 2022-08-29 15:00:00+00:00                      32.71
#
#       kemendagri_kabupaten_nama               street  level  median_length  \
# 58877                KOTA BOGOR  N8 Jalan Raya Bogor      2         1174.0
# 32803                KOTA BOGOR        Surya Kencana      1          816.0
# 8206                 KOTA BOGOR             Paledang      3          699.0
# 5532                 KOTA BOGOR  N9 Jalan Raya Ciawi      3          796.0
# 89233                KOTA BOGOR            Siliwangi      1         1168.0
#
#        median_delay  median_speed_kmh  total_records        id  ...  \
# 58877         114.0         19.920000             13  35717257  ...
# ...

# %%
df.drop('geometry', axis=1, inplace=True)

# %%
df.to_csv('../data/df_final.csv', sep=';', index=False)
